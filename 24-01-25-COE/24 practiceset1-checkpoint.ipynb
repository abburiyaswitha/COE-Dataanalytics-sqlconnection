# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cd
# Out:
# C:\Users\CVR

# %%
data=pd.read_csv("C:\\Users\\CVR\\Desktop\\energy_data.csv")

# %%
data
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...    ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88  21.40
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54  16.88
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44  17.11
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48  16.61
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64  16.03
#
# [768 rows x 10 columns]

# %%
data.head()
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0  0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28

# %%
data.tail()
# Out:
#        X1     X2     X3     X4   X5  X6   X7  X8     Y1     Y2
# 763  0.64  784.0  343.0  220.5  3.5   5  0.4   5  17.88  21.40
# 764  0.62  808.5  367.5  220.5  3.5   2  0.4   5  16.54  16.88
# 765  0.62  808.5  367.5  220.5  3.5   3  0.4   5  16.44  17.11
# 766  0.62  808.5  367.5  220.5  3.5   4  0.4   5  16.48  16.61
# 767  0.62  808.5  367.5  220.5  3.5   5  0.4   5  16.64  16.03

# %%
data.dtypes
# Out:
# X1    float64
# X2    float64
# X3    float64
# X4    float64
# X5    float64
# X6      int64
# X7    float64
# X8      int64
# Y1    float64
# Y2    float64
# dtype: object

# %%
data.shape
# Out:
# (768, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      768 non-null    float64
#  1   X2      768 non-null    float64
#  2   X3      768 non-null    float64
#  3   X4      768 non-null    float64
#  4   X5      768 non-null    float64
#  5   X6      768 non-null    int64
#  6   X7      768 non-null    float64
#  7   X8      768 non-null    int64
#  8   Y1      768 non-null    float64
#  9   Y2      768 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 60.1 KB

# %%
data.columns
# Out:
# Index(['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'Y1', 'Y2'], dtype='object')

# %%
d=data.iloc[1:6]

# %%
d
# Out:
#      X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 1  0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2  0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3  0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4  0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# 5  0.90  563.5  318.5  122.50  7.0   3  0.0   0  21.46  25.38

# %%
data.isnull()
# Out:
#         X1     X2     X3     X4     X5     X6     X7     X8     Y1     Y2
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 763  False  False  False  False  False  False  False  False  False  False
# 764  False  False  False  False  False  False  False  False  False  False
# 765  False  False  False  False  False  False  False  False  False  False
# 766  False  False  False  False  False  False  False  False  False  False
# 767  False  False  False  False  False  False  False  False  False  False
#
# [768 rows x 10 columns]

# %%
data.isnull().sum()
# Out:
# X1    0
# X2    0
# X3    0
# X4    0
# X5    0
# X6    0
# X7    0
# X8    0
# Y1    0
# Y2    0
# dtype: int64

# %%
data['X1']
# Out:
# 0      0.98
# 1      0.98
# 2      0.98
# 3      0.98
# 4      0.90
#        ...
# 763    0.64
# 764    0.62
# 765    0.62
# 766    0.62
# 767    0.62
# Name: X1, Length: 768, dtype: float64

# %%
data['X1'].unique
# Out:
# <bound method Series.unique of 0      0.98
# 1      0.98
# 2      0.98
# 3      0.98
# 4      0.90
#        ...
# 763    0.64
# 764    0.62
# 765    0.62
# 766    0.62
# 767    0.62
# Name: X1, Length: 768, dtype: float64>

# %%
data.drop_duplicates()
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...    ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88  21.40
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54  16.88
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44  17.11
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48  16.61
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64  16.03
#
# [768 rows x 10 columns]

# %%
data.describe()
# Out:
#                X1          X2          X3          X4         X5          X6  \
# count  768.000000  768.000000  768.000000  768.000000  768.00000  768.000000
# mean     0.764167  671.708333  318.500000  176.604167    5.25000    3.500000
# std      0.105777   88.086116   43.626481   45.165950    1.75114    1.118763
# min      0.620000  514.500000  245.000000  110.250000    3.50000    2.000000
# 25%      0.682500  606.375000  294.000000  140.875000    3.50000    2.750000
# 50%      0.750000  673.750000  318.500000  183.750000    5.25000    3.500000
# 75%      0.830000  741.125000  343.000000  220.500000    7.00000    4.250000
# max      0.980000  808.500000  416.500000  220.500000    7.00000    5.000000
#
#                X7         X8          Y1          Y2
# count  768.000000  768.00000  768.000000  768.000000
# mean     0.234375    2.81250   22.307201   24.587760
# std      0.133221    1.55096   10.090196    9.513306
# min      0.000000    0.00000    6.010000   10.900000
# ...

# %%
data['X1'].mean()
# Out:
# 0.7641666666666667

# %%
data['X1'].mode()
# Out:
# 0     0.62
# 1     0.64
# 2     0.66
# 3     0.69
# 4     0.71
# 5     0.74
# 6     0.76
# 7     0.79
# 8     0.82
# 9     0.86
# 10    0.90
# 11    0.98
# Name: X1, dtype: float64

# %%
data['X1'].median()
# Out:
# 0.75

# %%
data['X1'].std()
# Out:
# 0.10577747587475206

# %%
data.corr()
# Out:
#               X1            X2            X3            X4            X5  \
# X1  1.000000e+00 -9.919015e-01 -2.037817e-01 -8.688234e-01  8.277473e-01
# X2 -9.919015e-01  1.000000e+00  1.955016e-01  8.807195e-01 -8.581477e-01
# X3 -2.037817e-01  1.955016e-01  1.000000e+00 -2.923165e-01  2.809757e-01
# X4 -8.688234e-01  8.807195e-01 -2.923165e-01  1.000000e+00 -9.725122e-01
# X5  8.277473e-01 -8.581477e-01  2.809757e-01 -9.725122e-01  1.000000e+00
# X6  4.678592e-17 -3.459372e-17 -2.429499e-17 -5.830058e-17  4.492205e-17
# X7 -2.960552e-15  3.636925e-15 -8.567455e-17 -1.759011e-15  1.489134e-17
# X8 -7.107006e-16  2.438409e-15  2.067384e-16 -1.078071e-15 -2.920613e-17
# Y1  6.222722e-01 -6.581202e-01  4.556712e-01 -8.618283e-01  8.894307e-01
# Y2  6.343391e-01 -6.729989e-01  4.271170e-01 -8.625466e-01  8.957852e-01
#
#               X6            X7            X8        Y1        Y2
# X1  4.678592e-17 -2.960552e-15 -7.107006e-16  0.622272  0.634339
# ...

# %%
print(data.corr())
# Out:
#               X1            X2            X3            X4            X5  \
# X1  1.000000e+00 -9.919015e-01 -2.037817e-01 -8.688234e-01  8.277473e-01
# X2 -9.919015e-01  1.000000e+00  1.955016e-01  8.807195e-01 -8.581477e-01
# X3 -2.037817e-01  1.955016e-01  1.000000e+00 -2.923165e-01  2.809757e-01
# X4 -8.688234e-01  8.807195e-01 -2.923165e-01  1.000000e+00 -9.725122e-01
# X5  8.277473e-01 -8.581477e-01  2.809757e-01 -9.725122e-01  1.000000e+00
# X6  4.678592e-17 -3.459372e-17 -2.429499e-17 -5.830058e-17  4.492205e-17
# X7 -2.960552e-15  3.636925e-15 -8.567455e-17 -1.759011e-15  1.489134e-17
# X8 -7.107006e-16  2.438409e-15  2.067384e-16 -1.078071e-15 -2.920613e-17
# Y1  6.222722e-01 -6.581202e-01  4.556712e-01 -8.618283e-01  8.894307e-01
# Y2  6.343391e-01 -6.729989e-01  4.271170e-01 -8.625466e-01  8.957852e-01
#
#               X6            X7            X8        Y1        Y2
# X1  4.678592e-17 -2.960552e-15 -7.107006e-16  0.622272  0.634339
# ...

# %%
df = pd.DataFrame(data)#missing values before cleaning
print(df.isnull().sum())
# Out:
# X1    0
# X2    0
# X3    0
# X4    0
# X5    0
# X6    0
# X7    0
# X8    0
# Y1    0
# Y2    0
# dtype: int64

# %%
df = df.drop_duplicates()
df
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...    ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88  21.40
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54  16.88
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44  17.11
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48  16.61
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64  16.03
#
# [768 rows x 10 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'Y1', 'Y2']] = scaler.fit_transform(df[['X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'Y1', 'Y2']])

# %%
df['X6']=df['X6'].astype('category').cat.codes
print("\nCleaned Data:")
print(df)
# Out:
# Cleaned Data:
#            X1        X2        X3        X4   X5  X6        X7        X8  \
# 0    2.041777 -1.785875 -0.561951 -1.470077  1.0   0 -1.760447 -1.814575
# 1    2.041777 -1.785875 -0.561951 -1.470077  1.0   1 -1.760447 -1.814575
# 2    2.041777 -1.785875 -0.561951 -1.470077  1.0   2 -1.760447 -1.814575
# 3    2.041777 -1.785875 -0.561951 -1.470077  1.0   3 -1.760447 -1.814575
# 4    1.284979 -1.229239  0.000000 -1.198678  1.0   0 -1.760447 -1.814575
# ..        ...       ...       ...       ...  ...  ..       ...       ...
# 763 -1.174613  1.275625  0.561951  0.972512 -1.0   3  1.244049  1.411336
# 764 -1.363812  1.553943  1.123903  0.972512 -1.0   0  1.244049  1.411336
# 765 -1.363812  1.553943  1.123903  0.972512 -1.0   1  1.244049  1.411336
# 766 -1.363812  1.553943  1.123903  0.972512 -1.0   2  1.244049  1.411336
# 767 -1.363812  1.553943  1.123903  0.972512 -1.0   3  1.244049  1.411336
#
#            Y1        Y2
# 0   -0.670116 -0.342666
# 1   -0.670116 -0.342666
# ...

# %%
data
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...    ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88  21.40
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54  16.88
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44  17.11
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48  16.61
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64  16.03
#
# [768 rows x 10 columns]

# %%
df.dtypes
# Out:
# X1    float64
# X2    float64
# X3    float64
# X4    float64
# X5    float64
# X6       int8
# X7    float64
# X8    float64
# Y1    float64
# Y2    float64
# dtype: object

# %%
print(df.to_numpy())
# Out:
# [[ 2.04177671 -1.78587489 -0.56195149 ... -1.81457514 -0.67011624
#   -0.34266569]
#  [ 2.04177671 -1.78587489 -0.56195149 ... -1.81457514 -0.67011624
#   -0.34266569]
#  [ 2.04177671 -1.78587489 -0.56195149 ... -1.81457514 -0.67011624
#   -0.34266569]
#  ...
#  [-1.36381225  1.55394308  1.12390297 ...  1.41133622 -0.58185433
#   -0.78654401]
#  [-1.36381225  1.55394308  1.12390297 ...  1.41133622 -0.5778875
#   -0.83913623]
#  [-1.36381225  1.55394308  1.12390297 ...  1.41133622 -0.56202019
#   -0.9001432 ]]
